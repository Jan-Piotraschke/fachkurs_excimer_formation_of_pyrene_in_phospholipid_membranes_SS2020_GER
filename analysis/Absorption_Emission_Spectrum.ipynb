# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
EmiGe3 = pd.read_csv('data/020720_Pyren-EiPC_Device3_Spectrum003.txt', header=None, names=['EmiGe3'], sep=',', index_col=0)
ExGe3 = pd.read_csv('data/020720_Pyren-EiPC_Device3_Spectrum004.txt', header=None, names=['ExGe3'],sep=',', index_col=0)
EmiGe4 = pd.read_csv('data/020720_Pyren-EiPC_Device4_Spectrum0001.txt', header=None, names=['EmiGe4'],sep=',', index_col=0)
ExGe4 = pd.read_csv('data/020720_Pyren-EiPC_Device4_Spectrum0002.txt', header=None, names=['ExGe4'],sep=',', index_col=0)

# %%
ExGe3.loc[ExGe3['ExGe3'].idxmax()]
# Out:
# ExGe3    2.01813
# Name: 336, dtype: float64

# %%
fig = plt.figure(1, figsize=(8,4))
ax = plt.axes()
ax.set_xlabel('Wellenlänge $\lambda$ [nm]')
ax.set_ylabel('Fluoreszensintensität [a.u.]')

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.legend()
ax.yaxis.grid(alpha=0.4)

plt.plot(ExGe3['ExGe3'],'-',label="Anregungsspektrum")
plt.plot(EmiGe3['EmiGe3'],'-',label="Emissionsspektrum")
#plt.plot(ExGe4['ExGe4'],'-',label="Anregungsspektrum")
#plt.plot(EmiGe4['EmiGe4'],'-',label="Emissionsspektrum")

plt.legend(frameon=False)

plt.savefig('reports/Em_Ex_Scan_50_1.png',dpi=600, bbox_inches='tight')
plt.show()
# Out:
# No handles with labels found to put in legend.
